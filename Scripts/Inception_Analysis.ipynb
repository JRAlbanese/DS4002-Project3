# %% [markdown]
# ## THIS NOTEBOOK IS WRITTEN TO RUN ON GOOGLE COLAB

# %%
import sys
import sklearn
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from functools import partial

# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

np.random.seed(42)
tf.random.set_seed(42)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# !git clone https://github.com/JRAlbanese/DS4002-Project3
# Out:
# Cloning into 'DS4002-Project3'...
# remote: Enumerating objects: 3258, done.
# remote: Counting objects: 100% (1652/1652), done.
# remote: Compressing objects: 100% (1642/1642), done.
# remote: Total 3258 (delta 16), reused 1641 (delta 5), pack-reused 1606 (from 1)
# Receiving objects: 100% (3258/3258), 95.69 MiB | 26.69 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (3214/3214), done.
# Filtering content: 100% (3202/3202), 239.31 MiB | 2.89 MiB/s, done.

# %%
# %mv /content/DS4002-Project3/Resized_image_data/Valid/* /content/DS4002-Project3/Resized_image_data/
# %mv /content/DS4002-Project3/Resized_image_data/Training/* /content/DS4002-Project3/Resized_image_data/

# %%
import pandas as pd

#df = pd.read_csv('/content/combined_annotations.coco.csv')
df = pd.read_csv('/content/DS4002-Project3/Annotations/combined_annotations.coco.csv')
df = df.drop('info__year', axis = 1)
df = df.drop('info__version', axis = 1)
df = df.drop('info__url', axis = 1)#
df = df.drop('info__description', axis = 1)
df = df.drop('info__contributor', axis = 1)
df = df.drop('info__date_created', axis = 1)
df = df.drop('licenses__id', axis = 1)
df = df.drop('licenses__url', axis = 1)
df = df.drop('licenses__name', axis = 1)

# %%
print(df.head(10))
# Out:
#    categories__id        categories__name categories__supercategory  \
# 0             0.0             pedestrians                      none
# 1             1.0  children_wo_disability               pedestrians
# 2             2.0   elderly_wo_disability               pedestrians
# 3             3.0          non_vulnerable               pedestrians
# 4             4.0         with_disability               pedestrians
# 5             NaN                     NaN                       NaN
# 6             NaN                     NaN                       NaN
# 7             NaN                     NaN                       NaN
# 8             NaN                     NaN                       NaN
# 9             NaN                     NaN                       NaN
#
#    images__id  images__license  \
# 0         0.0              1.0
# 1         1.0              1.0
# 2         2.0              1.0
# 3         3.0              1.0
# 4         4.0              1.0
# 5         5.0              1.0
# 6         6.0              1.0
# 7         7.0              1.0
# 8         8.0              1.0
# 9         9.0              1.0
#
#                                    images__file_name  images__height  \
# 0  s_395_jpg.rf.62516cd87fe7892568b22244247bf08f.jpg          1390.0
# 1  586aec85-2b92-492d-9c6e-e89c476ff423-jumbo1x1_...          1440.0
# 2  wheelchairbound-man-climbing-stairs-business-6...           420.0
# 3  None1303_jpg.rf.6300aedec3642f3cc5de7a1239376f...           480.0
# 4  new-york-ny-may-16-600w-1733121173_jpg.rf.6324...           399.0
# 5  istockphoto-1222183673-612x612_jpeg.rf.634dbe7...           408.0
# 6    c_6_jpg.rf.63cca14bbb56a85e970331c0d95e52ab.jpg           159.0
# 7  j7mmny780_jpeg.rf.63dbde2aef01534726e41f95374c...           189.0
# 8  56fsehu7thk_jpeg.rf.640c8ed93f8caa5fd416b97112...           274.0
# 9  little-boy-going-cross-zebra-600w-2024513312_j...           420.0
#
#    images__width      images__date_captured  annotations__id  \
# 0          866.0  2022-12-09T13:35:51+00:00                0
# 1         1440.0  2022-12-09T13:35:51+00:00                1
# 2          600.0  2022-12-09T13:35:51+00:00                2
# 3          320.0  2022-12-09T13:35:51+00:00                3
# 4          600.0  2022-12-09T13:35:51+00:00                4
# 5          612.0  2022-12-09T13:35:51+00:00                5
# 6          318.0  2022-12-09T13:35:51+00:00                6
# 7          266.0  2022-12-09T13:35:51+00:00                7
# 8          184.0  2022-12-09T13:35:51+00:00                8
# 9          600.0  2022-12-09T13:35:51+00:00                9
#
#    annotations__image_id  annotations__category_id  annotations__bbox__001  \
# 0                      0                         4                     416
# 1                      0                         4                     255
# 2                      1                         4                      13
# 3                      2                         4                     285
# 4                      3                         2                     107
# 5                      3                         3                     196
# 6                      3                         3                       0
# 7                      3                         3                     260
# 8                      3                         3                     280
# 9                      4                         3                      99
#
#    annotations__bbox__002  annotations__bbox__003  annotations__bbox__004  \
# 0                     626                   82.08                  229.00
# 1                     610                  107.66                  238.00
# 2                     478                  559.68                  804.00
# 3                     115                  142.98                  152.50
# 4                      32                  109.76                  340.14
# 5                      81                   82.21                  246.73
# 6                      65                   53.17                  312.65
# 7                      75                   57.23                  216.03
# 8                      66                   39.76                  241.55
# 9                     128                   39.93                   74.71
#
#    annotations__area  annotations__iscrowd
# 0          18796.320                     0
# 1          25623.080                     0
# 2         449982.720                     0
# 3          21804.450                     0
# 4          37333.766                     0
# 5          20283.673                     0
# 6          16623.601                     0
# 7          12363.397                     0
# 8           9604.028                     0
# 9           2983.170                     0

# %%
#Extracting relevant details from annotations into separate dataframes.
categories = df[['categories__id', 'categories__name']]
image_paths = df[['images__file_name']]
image_paths = '/content/DS4002-Project3/Resized_image_data/' + image_paths
image_paths = image_paths['images__file_name'].tolist()
classes_annotation = df['annotations__category_id'].tolist()

bounding_boxes = list(zip(df['annotations__bbox__001'], df['annotations__bbox__002'], df['annotations__bbox__003'], df['annotations__bbox__004']))
#print(df.head(10))

print(len(image_paths))
print(len(bounding_boxes))
print(len(classes_annotation))
# Out:
# 4623
# 4623
# 4623

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.inception_v3 import preprocess_input

def load_image(image_path, target_size=(299, 299)):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = preprocess_input(image)  # Normalize the image as required by InceptionV3
    return image

def resize_bboxes(bboxes, original_size, target_size=(299, 299)):
    # Adjust bounding boxes to the new image size
    h, w = original_size
    new_h, new_w = target_size
    scale_x = new_w / w
    scale_y = new_h / h
    bboxes_resized = []
    for bbox in bboxes:
        xmin, ymin, xmax, ymax = bbox
        bboxes_resized.append([
            int(xmin * scale_x),
            int(ymin * scale_y),
            int(xmax * scale_x),
            int(ymax * scale_y),
        ])
    return bboxes_resized

# %%
images = []
bboxes = []
classes = []

#Assemble data together before splitting for test/train
for idx, img_path in enumerate(image_paths):
    try:
        print(img_path)
        img = load_image(img_path)
        images.append(img)
        bboxes.append(bounding_boxes[idx])
        classes.append(classes_annotation[idx])
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")

images = np.array(images)
bboxes = np.array(bboxes)
classes = np.array(classes)
# Out:
# Streaming output truncated to the last 5000 lines.
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# ...
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
#
# nan
# Error loading image nan: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object

# %%
print(images.shape)
print(bboxes.shape)
print(classes.shape)
# Out:
# (1601, 299, 299, 3)
# (1601, 4)
# (1601,)

# %%
from sklearn.model_selection import train_test_split

train_images, test_images, train_bboxes, test_bboxes, train_classes, test_classes = train_test_split(images, bboxes, classes, test_size=0.2)

# %%
from tensorflow.keras.utils import to_categorical
num_classes = 5
train_classes = to_categorical(train_classes, num_classes=num_classes)
test_classes = to_categorical(test_classes, num_classes=num_classes)

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam

#Mobilenet shape
input_shape = (299, 299, 3)
num_classes = 5

# instantiating model base
INbackbone = InceptionV3(input_shape=input_shape, include_top=False, weights='imagenet')
INbackbone.trainable = False

# output layers bounding box regression and class prediction
x = layers.GlobalAveragePooling2D()(INbackbone.output)
x = layers.Dense(1024, activation='relu')(x)
bbox_output = layers.Dense(4, activation='sigmoid', name='bbox')(x)  # Using sigmoid to scale between 0 and 1
class_output = layers.Dense(num_classes, activation='softmax', name='class')(x)

# Combine the outputs into a single model
Inceptionmodel = Model(inputs=INbackbone.input, outputs=[bbox_output, class_output])

# %%
Inceptionmodel.compile(optimizer='adam',
              loss={'bbox': 'mse', 'class': 'categorical_crossentropy'},  # Loss for bbox and classification
              metrics={'bbox': 'accuracy', 'class': 'accuracy'})

Inceptionmodel.fit(train_images, [train_bboxes, train_classes], epochs=30, batch_size=16)
# Out:
# Epoch 1/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - bbox_accuracy: 0.4639 - bbox_loss: 71039.2891 - class_accuracy: 0.3270 - class_loss: 1.6893 - loss: 71040.9766
# Epoch 2/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.3880 - class_loss: 1.4005 - loss: 71029.8984
# Epoch 3/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.4181 - class_loss: 1.3103 - loss: 71029.8047
# Epoch 4/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.4608 - class_loss: 1.2080 - loss: 71029.7031
# Epoch 5/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.5157 - class_loss: 1.1336 - loss: 71029.6250
# Epoch 6/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.5435 - class_loss: 1.0738 - loss: 71029.5781
# Epoch 7/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.5407 - class_loss: 1.0775 - loss: 71029.5703
# Epoch 8/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.4991 - class_loss: 1.2388 - loss: 71029.7344
# Epoch 9/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.5207 - class_loss: 1.2892 - loss: 71029.7891
# Epoch 10/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.5669 - class_loss: 1.0002 - loss: 71029.5000
# Epoch 11/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.6594 - class_loss: 0.8022 - loss: 71029.3047
# Epoch 12/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.7169 - class_loss: 0.7071 - loss: 71029.2109
# Epoch 13/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.7226 - class_loss: 0.6807 - loss: 71029.1797
# Epoch 14/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.7238 - class_loss: 0.7045 - loss: 71029.2031
# Epoch 15/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.7049 - class_loss: 0.7391 - loss: 71029.2422
# Epoch 16/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - bbox_accuracy: 0.4855 - bbox_loss: 71028.5000 - class_accuracy: 0.6426 - class_loss: 0.9051 - loss: 71029.4062
# Epoch 17/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - bbox_accuracy: 0.4854 - bbox_loss: 71028.5000 - class_accuracy: 0.5875 - class_loss: 1.1163 - loss: 71029.6172
# Epoch 18/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - bbox_accuracy: 0.4856 - bbox_loss: 71028.5000 - class_accuracy: 0.5771 - class_loss: 1.1582 - loss: 71029.6562
# Epoch 19/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - bbox_accuracy: 0.4909 - bbox_loss: 71028.5078 - class_accuracy: 0.6235 - class_loss: 0.9706 - loss: 71029.4688
# Epoch 20/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - bbox_accuracy: 0.4815 - bbox_loss: 71028.5078 - class_accuracy: 0.6496 - class_loss: 0.9364 - loss: 71029.4297
# Epoch 21/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - bbox_accuracy: 0.4843 - bbox_loss: 71028.5078 - class_accuracy: 0.6582 - class_loss: 0.8228 - loss: 71029.3125
# Epoch 22/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - bbox_accuracy: 0.4650 - bbox_loss: 71028.5078 - class_accuracy: 0.7287 - class_loss: 0.7403 - loss: 71029.2344
# Epoch 23/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - bbox_accuracy: 0.4388 - bbox_loss: 71028.5078 - class_accuracy: 0.6465 - class_loss: 0.8250 - loss: 71029.3281
# Epoch 24/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - bbox_accuracy: 0.4096 - bbox_loss: 71028.5078 - class_accuracy: 0.6185 - class_loss: 0.8899 - loss: 71029.3984
# Epoch 25/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - bbox_accuracy: 0.4364 - bbox_loss: 71028.5078 - class_accuracy: 0.6947 - class_loss: 0.6988 - loss: 71029.2031
# Epoch 26/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - bbox_accuracy: 0.4672 - bbox_loss: 71028.5078 - class_accuracy: 0.7306 - class_loss: 0.6360 - loss: 71029.1328
# Epoch 27/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - bbox_accuracy: 0.4531 - bbox_loss: 71028.5000 - class_accuracy: 0.8036 - class_loss: 0.5229 - loss: 71029.0234
# Epoch 28/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 72s 907ms/step - bbox_accuracy: 0.4355 - bbox_loss: 71028.5000 - class_accuracy: 0.8389 - class_loss: 0.4534 - loss: 71028.9609
# Epoch 29/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 69ms/step - bbox_accuracy: 0.4597 - bbox_loss: 71028.5000 - class_accuracy: 0.8704 - class_loss: 0.4109 - loss: 71028.9062
# Epoch 30/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - bbox_accuracy: 0.4480 - bbox_loss: 71028.5000 - class_accuracy: 0.8761 - class_loss: 0.3962 - loss: 71028.8906

# %%
test_loss, bbox_loss, class_loss, bbox_accuracy, class_accuracy = Inceptionmodel.evaluate(test_images, [test_bboxes, test_classes])

print(f"Test loss: {test_loss}")
print(f"Bounding Box Loss: {bbox_loss}")
print(f"Classification Loss: {class_loss}")
print(f"Bounding Box Accuracy: {bbox_accuracy}")
print(f"Classification Accuracy: {class_accuracy}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 25s 832ms/step - bbox_accuracy: 0.4347 - bbox_loss: 70127.9062 - class_accuracy: 0.2754 - class_loss: 3.4668 - loss: 69972.1172
# Test loss: 73765.234375
# Bounding Box Loss: 74716.9140625
# Classification Loss: 3.8597159385681152
# Bounding Box Accuracy: 0.43302181363105774
# Classification Accuracy: 0.2928348779678345
